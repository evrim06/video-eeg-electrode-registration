# %%
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np

import mne

# %%
#Load 3D scanner outputs

scan_path = Path("recordings/24ch_motor_11-12-2025_10-10 AM.elc")

#Read measured montage directly

24chan_montage = mne.channels.make_standard_montage(scan_path)
print(24chan_montage)

# %%
#Plot recording alone

my_montage.plot()  # 2D
fig = my_montage.plot(kind="3d", show=False)  # 3D
fig = fig.gca().view_init(azim=70, elev=15)  # set view angle for tutorial
plt.show
